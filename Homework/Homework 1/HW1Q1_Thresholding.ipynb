# %%
import cv2
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
#Read the image in colour and save it as img using imread function from cv2
img=cv2.imread("/content/for_watson.png", cv2.IMREAD_COLOR)
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(img)

# %%
_,img_thr = cv2.threshold(img,0,255,cv2.THRESH_BINARY)
plt.imshow(img_thr)

# %% [markdown]
# To decrypt the image I used binary thresholding with the function from openCV2 to change all pixel values with a value of 0 and below to 255. The message was shown as My Dear Watson, These tasks will lead us to him! Sherlock as can be seen above.
